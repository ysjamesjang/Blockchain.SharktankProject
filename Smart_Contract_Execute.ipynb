# %%
# Initialize dataframe.
from Company_Investor_df import concatenated

# Disable the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
concatenated
# Out:
#               Company  \
# 0          Parser.run
# 1            CancerIQ
# 2    Invitation codes
# 3             YCharts
# 4             Groupon
# 5             EVENTup
# 6            ParkWhiz
# 7         Food Genius
# 8        OpenAirplane
# 9         GiveForward
# 10        Rocketmiles
# 11          Classkick
# 12          Shortlist
# 13  Narrative Science
# 14           Packback
# 15     Storymix Media
# 16        Opternative
# 17           Shiftgig
# 18            Visible
# 19              Fooda
# 20           Cloudbot
# 21              Raise
# 22          FourKites
# 23      Sprout Social
# 24           SpotHero
#
#                                                            Slogan/Pitch  \
# 0                                        We extract data from websites.
# 1   Using Genetic Information to Predict, Pre-empt, and Prevent Cancer.
# 2                                               The referral community.
# ...
